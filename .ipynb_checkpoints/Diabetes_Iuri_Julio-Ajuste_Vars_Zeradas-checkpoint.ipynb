# %% [markdown]
# # Trabalho de _Machine Learning_
# ## Autores: Iúri Brandão e Júlio Scopel
# ### Para maiores detalhes sobre o notebook, ver README.md no repositório.

# %% [markdown]
# ## Importação das Bibliotecas Necessárias

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time

# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

#from sklearn import metrics
#from sklearn.metrics import accuracy_score

# Classificadores e relatórios:
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm, tree

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MaxAbsScaler
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Iniciando a análise exploratória do dataset

# %%
arquivo = 'diabetes.csv'

diabetes = pd.read_csv(arquivo)

#Para exibir as 5 primeiras linhas do df - se não tiver argumento:
diabetes.head(10).T
# Out:
#                                 0       1        2       3        4        5  \
# Pregnancies                 6.000   1.000    8.000   1.000    0.000    5.000
# Glucose                   148.000  85.000  183.000  89.000  137.000  116.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000   74.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000    0.000
# Insulin                     0.000   0.000    0.000  94.000  168.000    0.000
# BMI                        33.600  26.600   23.300  28.100   43.100   25.600
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288    0.201
# Age                        50.000  31.000   32.000  21.000   33.000   30.000
# Outcome                     1.000   0.000    1.000   0.000    1.000    0.000
#
#                                6        7        8        9
# Pregnancies                3.000   10.000    2.000    8.000
# Glucose                   78.000  115.000  197.000  125.000
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# **Ponto de atenção:** As varíaveis **glicose, pressão sanguínea, espessura de pele e insulina possuem valores zerados**, o que não correspondem à realidade. Isso será tratado adiante.

# %% [markdown]
# ## Bloxplot de alguns preditores, antes da _Feature Engineering_ para análise de _outliers_

# %%
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Insulin'])

# %%
sns.boxplot(x=diabetes['Outcome'], y=diabetes['Glucose'])

# %%
sns.boxplot(x=diabetes['Outcome'], y=diabetes['BloodPressure'])

# %%
sns.boxplot(x=diabetes['Outcome'], y=diabetes['SkinThickness'])

# %%
# Considerando que os valores zerados citados anteriormente não representam a realidade, o ajuste dos valores
# será com a média de cada variável, considerando o grupo das mulheres *sem* e *com* diabetes.
# No final será "plotado" histograma das variáveis:

# Glucose
diabetes.Glucose[(diabetes.Glucose==0) & (diabetes.Outcome==0)] = diabetes.Glucose[diabetes.Outcome==0].mean()
diabetes.Glucose[(diabetes.Glucose==0) & (diabetes.Outcome==1)] = diabetes.Glucose[diabetes.Outcome==1].mean()

# Skin Thickness
diabetes.SkinThickness[(diabetes.SkinThickness==0) & (diabetes.Outcome==0)] = diabetes.SkinThickness[diabetes.Outcome==0].mean()
diabetes.SkinThickness[(diabetes.SkinThickness==0) & (diabetes.Outcome==1)] = diabetes.SkinThickness[diabetes.Outcome==1].mean()

# Blood Pressure
diabetes.BloodPressure[(diabetes.BloodPressure==0) & (diabetes.Outcome==0)] = diabetes.BloodPressure[diabetes.Outcome==0].mean()
diabetes.BloodPressure[(diabetes.BloodPressure==0) & (diabetes.Outcome==1)] = diabetes.BloodPressure[diabetes.Outcome==1].mean()

#Insulin
diabetes.Insulin[(diabetes.Insulin==0) & (diabetes.Outcome==0)] = diabetes.Insulin[diabetes.Outcome==0].mean()
diabetes.Insulin[(diabetes.Insulin==0) & (diabetes.Outcome==1)] = diabetes.Insulin[diabetes.Outcome==1].mean()

# BMI
diabetes.BMI[(diabetes.BMI==0) & (diabetes.Outcome==0)] = diabetes.BMI[diabetes.Outcome==0].mean()
diabetes.BMI[(diabetes.BMI==0) & (diabetes.Outcome==1)] = diabetes.BMI[diabetes.Outcome==1].mean()

# Combinação dos histogramas:

set_cols2 = diabetes.loc[:,'Pregnancies':'Age']
set_cols2.hist(figsize=(15,10), bins=20, edgecolor='black')
plt.show()
# Out:
# <ipython-input-9-6bd056fc6b73>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes.Glucose[(diabetes.Glucose==0) & (diabetes.Outcome==0)] = diabetes.Glucose[diabetes.Outcome==0].mean()
# <ipython-input-9-6bd056fc6b73>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes.SkinThickness[(diabetes.SkinThickness==0) & (diabetes.Outcome==0)] = diabetes.SkinThickness[diabetes.Outcome==0].mean()
# <ipython-input-9-6bd056fc6b73>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Verificação de quantas amostras no dataset são de pessoas com ou sem diabetes (Outcome = 1 ou 0):
#sns.set(style="ticks")
sns.countplot(y=diabetes['Outcome']).set_title('Total de Amostras Sem e Com Diabetes (Outcome 0 e 1)')
# Out:
# Text(0.5, 1.0, 'Total de Amostras Sem e Com Diabetes (Outcome 0 e 1)')

# %% [markdown]
# ### Considerando que nenhum dos registros possui dados nulos, faremos uma análise da relação das variáveis:

# %%
corr = diabetes.corr()
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129898       0.209331       0.018064
# Glucose                      0.129898  1.000000       0.223775       0.179765
# BloodPressure                0.209331  0.223775       1.000000       0.138042
# SkinThickness                0.018064  0.179765       0.138042       1.000000
# Insulin                     -0.002905  0.431817       0.020926       0.250078
# BMI                          0.024268  0.235818       0.285223       0.548632
# DiabetesPedigreeFunction    -0.033523  0.138162       0.000679       0.156370
# Age                          0.544341  0.268613       0.326812       0.029980
# Outcome                      0.221898  0.495906       0.168405       0.213398
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.002905  0.024268                 -0.033523
# ...

# %%
# Fonte: https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Gráficos a serem utilizados na análise exploratória:

# %%
sns.distplot(diabetes['Glucose'])

# %%
sns.distplot(diabetes['Insulin'])

# %%
sns.distplot(diabetes['Age'])

# %%
sns.distplot(diabetes['BMI'])

# %%
sns.distplot(diabetes['Pregnancies'])

# %%
sns.relplot(x="Glucose", y="Insulin", hue="Outcome", size="Age", data=diabetes, legend='brief')

# %%
sns.relplot(x="Glucose", y="BloodPressure", hue="Outcome", size="Age", data=diabetes, legend='brief')

# %%
sns.relplot(x="Glucose", y="BMI", hue="Outcome", size="Age", data=diabetes, legend='brief')

# %%
# Visualização das relações de características, destacando "Outcome" (resultado):
#sns.pairplot(diabetes, hue="Outcome")

sns.pairplot(diabetes, height=3, vars=["Glucose", "Insulin", "BMI", "Age"], hue="Outcome")
#sns.pairplot(diabetes, height=3, vars=["Glucose", "Insulin", "BMI", "Age", "SkinThickness"], hue="Outcome")

# %% [markdown]
# #  NORMALIZAÇÃO DOS DADOS

# %%
df_preditores = diabetes.drop(['Outcome'],axis = 1)

# Instancia o MaxAbsScaler
p=MaxAbsScaler()
# Analisa os dados e prepara o padronizador
p.fit(df_preditores)
# Analisa os dados e prepara o padronizador
df_normalizado = p.transform(df_preditores)
diabetes_normalizado = pd.DataFrame(df_normalizado, columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age'])
diabetes_normalizado['Outcome'] = diabetes['Outcome']

#Dataset normalizado
diabetes_normalizado
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.118600  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.081314  0.396423
# 2       0.470588  0.919598       0.524590       0.223881  0.118600  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.507538       0.622951       0.484848  0.212766  0.490313
# 764     0.117647  0.613065       0.573770       0.272727  0.081314  0.548435
# 765     0.294118  0.608040       0.590164       0.232323  0.132388  0.390462
# 766     0.058824  0.633166       0.491803       0.223881  0.118600  0.448584
# 767     0.058824  0.467337       0.573770       0.313131  0.081314  0.453055
#
# ...

# %% [markdown]
# #  IMPORTÂNCIA DE CADA ATRIBUTO

# %%
# URL base: https://medium.com/@dspaulolima/encontrando-atributos-mais-importantes-em-dados-de-diabetes-b39d644c275c

# UTILIZANDO RANDOM FOREST PARA ENCONTRAR IMPORTÂNCIA DOS ATRIBUTOS

var_pred = diabetes_normalizado.drop(columns='Outcome')
var_target = diabetes_normalizado.Outcome

rfclf = RandomForestClassifier(n_estimators=100, max_depth=5)
rfclf = rfclf.fit(var_pred,var_target)

importances = rfclf.feature_importances_

std = np.std([tree.feature_importances_ for tree in rfclf.estimators_], axis=0)

indices = np.argsort(importances)[::-1]

# IMPRIMINDO RANKING DOS ATRIBUTOS
print("Feature ranking:")

for f in range(var_pred.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# PLOTAGEM DAS IMPORTÂNCIAS
plt.figure(1, figsize=(15, 10))

plt.title("Feature importances")
plt.bar(range(var_pred.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")

plt.xticks(range(var_pred.shape[1]), var_pred.columns[indices],rotation=90)
plt.xlim([-1, var_pred.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 4 (0.381049)
# 2. feature 1 (0.201819)
# 3. feature 3 (0.173075)
# 4. feature 7 (0.072097)
# 5. feature 5 (0.070803)
# 6. feature 6 (0.040874)
# 7. feature 0 (0.038553)
# 8. feature 2 (0.021729)

# %% [markdown]
# ## Separação do _dataset_ em treino e teste, para construção e execução dos modelos:

# %%
#Split arrays or matrices into random train and test subsets
#https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

from sklearn.model_selection import train_test_split

# A variável X conterá a coluna Outcome, e y terá o DataFrame menos a coluna que é nosso "target":
X = diabetes_normalizado.drop(['Outcome'], axis=1)
y = diabetes_normalizado.Outcome # Target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=314)

# %%
#Usando o GridSearchCV para buscar os melhores parâmetros
rfc = RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [100, 200,300],
    'max_depth' : [4,5,6],
    'criterion' :['gini', 'entropy']
}

teste = GridSearchCV(estimator=rfc, param_grid=param_grid)
teste.fit(X_train, y_train)

#Imprime melhores parâmetros para a random forest
print(teste.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 200}

# %%
# Busca dos melhores parâmetros para a árvore de decisão:
clf_tree=tree.DecisionTreeClassifier()
parameters={'min_samples_split' : range(10,500,20),'max_depth': range(1,20,2)}
clf=GridSearchCV(clf_tree,parameters)
clf.fit(X_train, y_train)
print(clf.best_params_)
# Out:
# {'max_depth': 19, 'min_samples_split': 30}

# %%
# Criando os modelos e adicionando-os a um array:
classifiers = []

model1 = GaussianNB()
classifiers.append(model1)

model2 = tree.DecisionTreeClassifier()
classifiers.append(model2)

model3 = RandomForestClassifier()
classifiers.append(model3)

#Parametros definidos pelo GridSearchCV
model4 = RandomForestClassifier(criterion = 'entropy', max_depth = 6, n_estimators = 200)
classifiers.append(model4)

model5 = tree.DecisionTreeClassifier(max_depth = 11, min_samples_split = 30)
classifiers.append(model5)

# %%
# Exibindo o conteúdo do array:
classifiers
# Out:
# [GaussianNB(),
#  DecisionTreeClassifier(),
#  RandomForestClassifier(),
#  RandomForestClassifier(criterion='entropy', max_depth=6, n_estimators=200),
#  DecisionTreeClassifier(max_depth=11, min_samples_split=30)]

# %%
for clf in classifiers:
    initial_time = time.time()
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    tempo = time.time()-initial_time
    acc = accuracy_score(y_test, y_pred)
    #print("Accuracy of %s is %s"%(clf, acc))
    print("Tempo de processamento o modelo: {}\n".format(tempo))
    
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred)
    
    print('\n*** Confusion Matrix of %s ***'%(clf))
    sns.heatmap(cm, annot=True, cmap='RdPu')
    plt.show()
    print('==================================================================')
# Out:
# Tempo de processamento o modelo: 0.003957509994506836
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       103
#            1       0.72      0.55      0.62        51
#
#     accuracy                           0.78       154
#    macro avg       0.76      0.72      0.73       154
# weighted avg       0.77      0.78      0.77       154
#
#
# *** Confusion Matrix of GaussianNB() ***
# ...
# Tempo de processamento o modelo: 0.00496220588684082
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       103
#            1       0.77      0.80      0.79        51
#
#     accuracy                           0.86       154
#    macro avg       0.84      0.84      0.84       154
# weighted avg       0.86      0.86      0.86       154
#
#
# *** Confusion Matrix of DecisionTreeClassifier() ***
# ...
# Tempo de processamento o modelo: 0.1466050148010254
#
# ...

# %% [markdown]
# # Resultado
#
# A acurácia do Random Forest foi de 0,78 enquanto a da Decision Tree foi de 0,69. Era esperado que a acurácia do Random Forest fosse maior já que a ele cria uma combinação (ensemble) de árvores de decisão, treinados com o método de bagging.
# Por outro lado, o tempo de processamento (treinamento e predição) do Random Forest é muito maior que os outros dois algoritmos usados, isso se deve justamente ao fato da utilização do ensemble e do bagging, processos inerentes ao algoritmo.
#
# Ao utilizar os parâmetros determinados pelo GridSearchCV a acurácia tende a ser maior tanto no Random Forest quanto no Decision Tree. No caso do Random Forest o tempo de processamento aumentou significativamente, já no Decision Tree o tempo diminuiu.
#
# O Naive Bayes teve um bom resultado e como grande a vantagem de possuir um tempo de processamento menor que os outros dois tipos de algoritmos testados. Não utilizamos o GridsearchCV pois não obtivemos resultados satisfatórios.
